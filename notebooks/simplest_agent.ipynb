# %% [markdown]
# # Creating a Simple Agent with Tracing

# %%
import dotenv
import os

from openai import OpenAI

dotenv.load_dotenv()

if not os.environ.get("OPENAI_API_KEY"):
    print(
        """Error: OPENAI_API_KEY environment variable not set. Please copy the .env.template file as .env and fill it in.
    
    You can execute these commands in the terminal to get started:
    cp .env.template .env
    code .env
    """
    )

# Test OpenAI Access
print(
    OpenAI()
    .responses.create(
        model=os.environ["OPENAI_DEFAULT_MODEL"], input="Say: We are up and running!"
    )
    .output_text
)
# Out:
# We are up and running!

# %%
from agents import Agent, Runner, trace
from openai.types.responses import ResponseTextDeltaEvent

# %% [markdown]
# Create a simple Nutrition Assistant Agent

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant giving out nutrition advice.
    You give concise answers.
    """
)

# %% [markdown]
# Let's execute the Agent:

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(nutrition_agent, "How healthy are bananas?")

print(result)
# Out:
# RunResult:
# - Last agent: Agent(name="Nutrition Assistant", ...)
# - Final output (str):
#     Overall, yes—bananas are healthy when eaten in moderation.
#
#     Key points:
#     - Nutrients: good source of potassium, vitamin C, vitamin B6, and fiber.
#     - Energy: about 100 calories per medium fruit; natural sugars provide quick energy.
#     - Digestion: fiber supports gut health; unripe bananas have resistant starch (prebiotic).
#     - Health implications: can help with blood pressure and heart health; portion control matters for diabetes or calorie goals.
#     - Considerations: allergies possible; ripe bananas are higher in sugar than unripe.
#
#     Tips: pair with protein/fat for staying power, and choose based on your taste and energy needs.
# - 2 new item(s)
# - 1 raw response(s)
# - 0 input guardrail result(s)
# - 0 output guardrail result(s)
# (See `RunResult` for more details)

# %% [markdown]
# Streaming the answer to the screen, token by token

# %%
response_stream = Runner.run_streamed(nutrition_agent, "How healthy are bananas?")

async for event in response_stream.stream_events():
    if event.type == "raw_response_event" and isinstance(
        event.data, ResponseTextDeltaEvent
    ):
        print(event.data.delta, end="", flush=True)
# Out:
# Bananas are quite healthy when eaten as part of a balanced diet.
#
# Key benefits:
# - Good source of potassium, vitamin B6, vitamin C, and dietary fiber
# - Low in fat and calories per fruit
# - Quick energy from natural sugars
#
# Things to note:
# - Ripeness affects sugar content (ripe bananas are sweeter).
# - Moderation for those watching blood sugar or total carbohydrate intake.
# - Pair with protein or fat for better satiety.
#
# Overall: a convenient, nutritious snack or addition to meals.

# %% [markdown]
# _Good Job!_
